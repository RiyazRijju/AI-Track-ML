# %%
import math
x = 1 #Initialise x
y = 2 #Initialise y
lr = 0.01 #Learning rate
min = 0.000001 #minimum threshold value
delta_x = 1 #Initialising Δx
delta_y = 1 #Initialising Δy
max_iters = 1000 #Maximum number of iterations  
iters_count = 0 #Counting Iterations

#f(x) = 3x^2 + 5e^-y + 10

#find the value of gradient at x
def gradient(x_value, y_value):
  return (6 * x, -5 * math.exp(-y))

#finding local minima
while max(abs(delta_x), abs(delta_y)) > min and (iters_count < max_iters):
  grad_value_x, grad_value_y = gradient(x, y)
  delta_x = -lr * grad_value_x
  delta_y = -lr * grad_value_y
  iters_count += 1
  x += delta_x
  y += delta_y
  print(f"Iteration: {iters_count}\tValue of x: {x}, \tValue of y: {y}")

print(f"\nThe local minima occurs at: {x}, {y}")
# Out:
# Iteration: 1	Value of x: 0.94, 	Value of y: 2.0067667641618305
# Iteration: 2	Value of x: 0.8835999999999999, 	Value of y: 2.0134878937996006
# Iteration: 3	Value of x: 0.830584, 	Value of y: 2.0201640013229807
# Iteration: 4	Value of x: 0.7807489599999999, 	Value of y: 2.026795686882592
# Iteration: 5	Value of x: 0.7339040224, 	Value of y: 2.033383538695303
# Iteration: 6	Value of x: 0.6898697810559999, 	Value of y: 2.039928133358798
# Iteration: 7	Value of x: 0.64847759419264, 	Value of y: 2.0464300361558445
# Iteration: 8	Value of x: 0.6095689385410815, 	Value of y: 2.0528898013486585
# Iteration: 9	Value of x: 0.5729948022286167, 	Value of y: 2.059307972463752
# Iteration: 10	Value of x: 0.5386151140948996, 	Value of y: 2.0656850825676334
# Iteration: 11	Value of x: 0.5062982072492056, 	Value of y: 2.0720216545337036
# Iteration: 12	Value of x: 0.4759203148142533, 	Value of y: 2.0783182013006947
# Iteration: 13	Value of x: 0.4473650959253981, 	Value of y: 2.0845752261229586
# ...
